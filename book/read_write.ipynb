# %%
import numpy as np

# use OpenCV 

import cv2

#img_cv = cv2.imread("peppers_color.tif")
img_cv = cv2.imread("images.jpeg")
print("OpenCV:")
print(type(img_cv))
print(" shape:", img_cv.shape)
print(" dtype:", img_cv.dtype)
print(" min/max:", img_cv.min(), img_cv.max())


# OpenCV visualization (desktop only)
# cv2.imshow("OpenCV image", img_cv)
# cv2.waitKey(0)
# cv2.destroyAllWindows()

# Save the image
cv2.imwrite("images_cv.jpeg", img_cv)
# Out:
# OpenCV:
# <class 'numpy.ndarray'>
#  shape: (451, 679, 3)
#  dtype: uint8
#  min/max: 0 255
# True

# %%
#Use ImageIO

import imageio.v2 as imageio

#img_io = imageio.imread("peppers_color.tif")
img_io = imageio.imread("images.jpeg")
print("ImageIO:")
print(type(img_io))
print(" shape:", img_io.shape)
print(" dtype:", img_io.dtype)
print(" min/max:", img_io.min(), img_io.max())


# --- Check the difference between the two arrays  (convert OpenCV in RGB) ---
img_cv_rgb = cv2.cvtColor(img_cv, cv2.COLOR_BGR2RGB)

diff = np.abs(img_cv_rgb.astype(int) - img_io.astype(int))
print("\nMaximum difference between OpenCV (converted  in RGB) and  Imageio:", diff.max())

# Save the image

#Make sure your array dtype is np.uint8 for normal 8-bit images.

# If you have floating-point arrays (0–1), scale them to 0–255 first:

#image_uint8 = (image_float * 255).astype(np.uint8)
imageio.imwrite("output_image_imageio.jpeg", img_io)
# Out:
# ImageIO:
# <class 'numpy.ndarray'>
#  shape: (451, 679, 3)
#  dtype: uint8
#  min/max: 0 255
#
# Maximum difference between OpenCV (converted  in RGB) and  Imageio: 0

# %%
# use pyplot

import matplotlib.pyplot as plt

#img_plt = plt.imread("peppers_color.tif")
img_plt = plt.imread("images.jpeg")
print("Matplotlib:")
print(" shape:", img_plt.shape)
print(" dtype:", img_plt.dtype)
print(" min/max:", img_plt.min(), img_plt.max())


# Matplotlib visualization
plt.imshow(img_plt)
plt.title("Matplotlib image")
plt.axis('off')
plt.show()

# Save 
plt.imsave("image_plt.jpeg", img_plt)  

# if the image is grayscale: 
#plt.imsave("image_plt_bn.jpeg", img_plt,cmap="gray")
# Out:
# Matplotlib:
#  shape: (451, 679, 3)
#  dtype: uint8
#  min/max: 0 255

# %%
 

# Dicom file
import pydicom

# Read  dicom file
ds = pydicom.dcmread("proj.dcm")

# Show the main metadata
print(ds)

# Show the image
plt.figure()
plt.imshow(ds.pixel_array, cmap='gray')
plt.show()

ds1 = pydicom.dcmread("reco.dcm")

# Show the main metadata
print(ds1)
# Out:
# Dataset.file_meta -------------------------------
# (0002,0000) File Meta Information Group Length  UL: 206
# (0002,0001) File Meta Information Version       OB: b'\x00\x01'
# (0002,0002) Media Storage SOP Class UID         UI: Digital Mammography X-Ray Image Storage - For Processing
# (0002,0003) Media Storage SOP Instance UID      UI: 2.16.840.1.113669.632.25.1.103374.20240502120725128.10.3.5
# (0002,0010) Transfer Syntax UID                 UI: Explicit VR Little Endian
# (0002,0012) Implementation Class UID            UI: 1.2.276.0.7230010.3.0.3.6.3
# (0002,0013) Implementation Version Name         SH: 'OFFIS_DCMTK_363'
# -------------------------------------------------
# (0008,0005) Specific Character Set              CS: 'ISO_IR 100'
# (0008,0008) Image Type                          CS: ['ORIGINAL', 'PRIMARY', '', '', '']
# (0008,0016) SOP Class UID                       UI: Digital Mammography X-Ray Image Storage - For Processing
# (0008,0018) SOP Instance UID                    UI: 2.16.840.1.113669.632.25.1.103374.20240502120725128.10.3.5
# (0008,0020) Study Date                          DA: '20240502'
# (0008,0021) Series Date                         DA: '20240502'
# (0008,0022) Acquisition Date                    DA: '20240502'
# (0008,0023) Content Date                        DA: '20240502'
# (0008,0030) Study Time                          TM: '090232'
# (0008,0031) Series Time                         TM: '120715'
# (0008,0032) Acquisition Time                    TM: '120725'
# (0008,0033) Content Time                        TM: '120725'
# (0008,0050) Accession Number                    SH: ''
# (0008,0060) Modality                            CS: 'MG'
# (0008,0068) Presentation Intent Type            CS: 'FOR PROCESSING'
# (0008,0070) Manufacturer                        LO: 'IMS GIOTTO S.p.A.'
# (0008,0090) Referring Physician's Name          PN: ''
# (0008,1010) Station Name                        SH: 'GIOTTO CLASS'
# (0008,1050) Performing Physician's Name         PN: ''
# (0008,1070) Operators' Name                     PN: ''
# (0008,1090) Manufacturer's Model Name           LO: 'GIOTTO CLASS'
# (0008,2218)  Anatomic Region Sequence  1 item(s) ----
#    (0008,0100) Code Value                          SH: 'T-04000'
#    (0008,0102) Coding Scheme Designator            SH: 'SRT'
#    (0008,0104) Code Meaning                        LO: 'Breast'
#    ---------
# (0008,3010) Irradiation Event UID               UI: 2.16.840.1.113669.632.25.1.103374.20240502120715307.8
# (0010,0010) Patient's Name                      PN: 'DBT^31 PROJ'
# (0010,0020) Patient ID                          LO: 'MADAVERO'
# (0010,0030) Patient's Birth Date                DA: '19840328'
# (0010,0040) Patient's Sex                       CS: 'F'
# (0010,1010) Patient's Age                       AS: '040Y'
# (0010,1020) Patient's Size                      DS: None
# (0010,1030) Patient's Weight                    DS: None
# (0018,0015) Body Part Examined                  CS: 'BREAST'
# (0018,0060) KVP                                 DS: '27'
# (0018,1000) Device Serial Number                LO: '103374'
# (0018,1020) Software Versions                   LO: 'Raffaello 4.19.8.0 - IMSProc 4.17.3.2 - Tiziano 4.15.0.3'
# (0018,1030) Protocol Name                       LO: 'Mammography'
# (0018,1110) Distance Source to Detector         DS: '688.9'
# (0018,1111) Distance Source to Patient          DS: '672.0'
# (0018,1114) Estimated Radiographic Magnificatio DS: '1.000'
# (0018,1147) Field of View Shape                 CS: 'RECTANGLE'
# (0018,1149) Field of View Dimension(s)          IS: [297, 233]
# (0018,1150) Exposure Time                       IS: '38'
# (0018,1151) X-Ray Tube Current                  IS: '104'
# (0018,1152) Exposure                            IS: '4'
# (0018,1153) Exposure in uAs                     IS: '4050'
# (0018,1160) Filter Type                         SH: 'STRIP'
# (0018,1164) Imager Pixel Spacing                DS: [0.0829, 0.0829]
# (0018,1166) Grid                                CS: 'NONE'
# (0018,1190) Focal Spot(s)                       DS: '0.3'
# (0018,1191) Anode Target Material               CS: 'TUNGSTEN'
# (0018,11A0) Body Part Thickness                 DS: '40'
# (0018,11A2) Compression Force                   DS: '9.8'
# (0018,11A4) Paddle Description                  LO: '24x30'
# (0018,1405) Relative X-Ray Exposure             IS: '2075'
# (0018,1508) Positioner Type                     CS: 'MAMMOGRAPHIC'
# (0018,1510) Positioner Primary Angle            DS: '0'
# (0018,1511) Positioner Secondary Angle          DS: '0'
# (0018,1530) Detector Primary Angle              DS: '0'
# (0018,1531) Detector Secondary Angle            DS: '0.907889'
# (0018,5101) View Position                       CS: 'CC'
# (0018,7001) Detector Temperature                DS: '32'
# (0018,7004) Detector Type                       CS: 'DIRECT'
# (0018,7005) Detector Configuration              CS: 'AREA'
# (0018,700A) Detector ID                         SH: 'AP01-23387'
# (0018,700C) Date of Last Detector Calibration   DA: '20240418'
# (0018,701A) Detector Binning                    DS: [1, 1]
# (0018,7020) Detector Element Physical Size      DS: [0.085, 0.085]
# (0018,7022) Detector Element Spacing            DS: [0.085, 0.085]
# (0018,702B) Detector Manufacturer's Model Name  LO: 'SCREEN+'
# (0018,7050) Filter Material                     CS: 'SILVER'
# (0018,7052) Filter Thickness Minimum            DS: '0.05'
# (0018,7054) Filter Thickness Maximum            DS: '0.05'
# (0018,7060) Exposure Control Mode               CS: 'AUTOMATIC'
# (0018,7062) Exposure Control Mode Description   LT: Array of 184 elements
# (0018,8151) X-Ray Tube Current in uA            DS: '104400'
# (0018,9559) Positioner Primary Angle Direction  CS: 'CW'
# (0020,000D) Study Instance UID                  UI: 2.16.840.1.113669.632.25.1.103374.20240502090232863.1
# (0020,000E) Series Instance UID                 UI: 2.16.840.1.113669.632.25.1.103374.20240502120715244.2.5
# (0020,0010) Study ID                            SH: '581-193'
# (0020,0011) Series Number                       IS: '18'
# (0020,0013) Instance Number                     IS: '10'
# (0020,0020) Patient Orientation                 CS: ['P', 'L']
# (0020,0052) Frame of Reference UID              UI: 2.16.840.1.113669.632.25.1.103374.20240502120715286.6
# (0020,0062) Image Laterality                    CS: 'R'
# (0020,1040) Position Reference Indicator        LO: ''
# (0028,0002) Samples per Pixel                   US: 1
# (0028,0004) Photometric Interpretation          CS: 'MONOCHROME1'
# (0028,0010) Rows                                US: 3580
# (0028,0011) Columns                             US: 2812
# (0028,0100) Bits Allocated                      US: 16
# (0028,0101) Bits Stored                         US: 13
# (0028,0102) High Bit                            US: 12
# (0028,0103) Pixel Representation                US: 0
# (0028,0120) Pixel Padding Value                 US: 7500
# (0028,0121) Pixel Padding Range Limit           US: 1952
# (0028,0300) Quality Control Image               CS: 'YES'
# (0028,0301) Burned In Annotation                CS: 'NO'
# (0028,1040) Pixel Intensity Relationship        CS: 'LIN'
# (0028,1041) Pixel Intensity Relationship Sign   SS: 1
# (0028,1052) Rescale Intercept                   DS: '0'
# (0028,1053) Rescale Slope                       DS: '1'
# (0028,1054) Rescale Type                        LO: 'US'
# (0028,1300) Breast Implant Present              CS: 'NO'
# (0028,1350) Partial View                        CS: 'NO'
# (0028,2110) Lossy Image Compression             CS: '00'
# (0040,0244) Performed Procedure Step Start Date DA: '20240502'
# (0040,0245) Performed Procedure Step Start Time TM: '090232'
# (0040,0253) Performed Procedure Step ID         SH: '20231333'
# (0040,0254) Performed Procedure Step Descriptio LO: ''
# (0040,0314) Half Value Layer                    DS: '0.518'
# (0040,0316) Organ Dose                          DS: '0.00062'
# (0040,0318) Organ Exposed                       CS: 'BREAST'
# (0040,0555)  Acquisition Context Sequence  0 item(s) ----
# (0040,8302) Entrance Dose in mGy                DS: '0.179'
# (0040,8303) Entrance Dose Derivation            CS: 'IAK'
# (0054,0220)  View Code Sequence  1 item(s) ----
#    (0008,0100) Code Value                          SH: 'R-10242'
#    (0008,0102) Coding Scheme Designator            SH: 'SRT'
#    (0008,0104) Code Meaning                        LO: 'cranio-caudal'
#    (0054,0222)  View Modifier Code Sequence  0 item(s) ----
#    ---------
# (1269,0010) Private Creator                     LO: 'Raffaello Biopsy Private Code'
# (1269,1001) Private tag data                    IS: '0'
# (1271,0010) Private Creator                     LO: 'Raffaello Mammography Private Code'
# (1271,1020) Private tag data                    IS: '3'
# (1271,1021) Private tag data                    IS: '2'
# (1271,1022) Private tag data                    IS: '0'
# (1271,1025) Private tag data                    IS: '0'
# (1271,1038) Private tag data                    LO: 'YES'
# (1271,1039) Private tag data                    US: [268, 268]
# (1271,1040) Private tag data                    US: [536, 536]
# (1271,1041) Private tag data                    LO: ['CURRENT', 'STANDARD']
# (1271,1053) Private tag data                    LO: '1.00'
# (1271,1054) Private tag data                    IS: '0'
# (1271,1055) Private tag data                    LO: '1952'
# (1271,1070) Private tag data                    DS: '648.8'
# (1271,1071) Private tag data                    DS: '0.000'
# (1271,1072) Private tag data                    DS: '0.000'
# (1271,1073) Private tag data                    DS: '0.000'
# (1271,1074) Private tag data                    IS: '1792'
# (1271,1075) Private tag data                    IS: '0'
# (1271,1076) Private tag data                    DS: '0.964'
# (1271,1077) Private tag data                    DS: '0.964'
# (1271,1078) Private tag data                    DS: '0.964'
# (1271,1079) Private tag data                    IS: '10'
# (1271,1080) Private tag data                    IS: '21'
# (1271,1082) Private tag data                    IS: '1'
# (1271,1083) Private tag data                    LO: ''
# (1271,1084) Private tag data                    LO: ''
# (1271,1086) Private tag data                    LT: Array of 73 elements
# (1271,1087) Private tag data                    IS: '6'
# (1271,1088) Private tag data                    IS: '0'
# (1271,1091) Private tag data                    LO: '1.4'
# (1271,1093) Private tag data                    IS: '0'
# (1271,1097) Private tag data                    IS: '7500'
# (1271,1098) Private tag data                    IS: '2'
# (1271,1099) Private tag data                    IS: '2'
# (1271,109A) Private tag data                    IS: '2'
# (1271,109B) Private tag data                    IS: '2'
# (1271,10A1) Private tag data                    US: 0
# (1271,10A4) Private tag data                    LO: ''
# (1271,10A5) Private tag data                    SS: 0
# (1271,10B2) Private tag data                    DS: '-0.90789'
# (2050,0020) Presentation LUT Shape              CS: 'INVERSE'
# (7FE0,0010) Pixel Data                          OW: Array of 20133920 elements
# Dataset.file_meta -------------------------------
# (0002,0000) File Meta Information Group Length  UL: 206
# (0002,0001) File Meta Information Version       OB: b'\x00\x01'
# (0002,0002) Media Storage SOP Class UID         UI: Breast Tomosynthesis Image Storage
# (0002,0003) Media Storage SOP Instance UID      UI: 2.16.840.1.113669.632.25.1.106974.20220502080325696.2.3.7
# (0002,0010) Transfer Syntax UID                 UI: Explicit VR Little Endian
# (0002,0012) Implementation Class UID            UI: 1.2.276.0.7230010.3.0.3.6.3
# (0002,0013) Implementation Version Name         SH: 'OFFIS_DCMTK_363'
# -------------------------------------------------
# (0008,0005) Specific Character Set              CS: 'ISO_IR 192'
# (0008,0008) Image Type                          CS: ['DERIVED', 'PRIMARY', 'TOMOSYNTHESIS', 'NONE']
# (0008,0012) Instance Creation Date              DA: '20220502'
# (0008,0013) Instance Creation Time              TM: '080359'
# (0008,0016) SOP Class UID                       UI: Breast Tomosynthesis Image Storage
# (0008,0018) SOP Instance UID                    UI: 2.16.840.1.113669.632.25.1.106974.20220502080325696.2.3.7
# (0008,0020) Study Date                          DA: '20220412'
# (0008,0021) Series Date                         DA: '20220412'
# (0008,0023) Content Date                        DA: '20220502'
# (0008,0030) Study Time                          TM: '155257'
# (0008,0031) Series Time                         TM: '155800'
# (0008,0033) Content Time                        TM: '080359'
# (0008,0050) Accession Number                    SH: ''
# (0008,0060) Modality                            CS: 'MG'
# (0008,0070) Manufacturer                        LO: 'IMS GIOTTO S.p.A.'
# (0008,0090) Referring Physician's Name          PN: ''
# (0008,1010) Station Name                        SH: 'GIOTTO CLASS'
# (0008,103E) Series Description                  LO: 'RCC CANOVA'
# (0008,1050) Performing Physician's Name         PN: ''
# (0008,1070) Operators' Name                     PN: ''
# (0008,1090) Manufacturer's Model Name           LO: 'GIOTTO CLASS'
# (0008,1111)  Referenced Performed Procedure Step Sequence  1 item(s) ----
#    (0008,1150) Referenced SOP Class UID            UI: Modality Performed Procedure Step SOP Class
#    (0008,1155) Referenced SOP Instance UID         UI: ''
#    ---------
# (0008,3011)  Source Irradiation Event Sequence  1 item(s) ----
#    (0008,3010) Irradiation Event UID               UI: 2.16.840.1.113669.632.25.1.106974.20220412155800487.8
#    ---------
# (0008,9205) Pixel Presentation                  CS: 'MONOCHROME'
# (0008,9206) Volumetric Properties               CS: 'VOLUME'
# (0008,9207) Volume Based Calculation Technique  CS: 'NONE'
# (0010,0010) Patient's Name                      PN: 'MORTADELLA_TOMO^MORTADELLA_TOMO'
# (0010,0020) Patient ID                          LO: 'MORTADELLA_TOMO'
# (0010,0030) Patient's Birth Date                DA: '19840328'
# (0010,0040) Patient's Sex                       CS: 'F'
# (0010,1010) Patient's Age                       AS: '038Y'
# (0018,0015) Body Part Examined                  CS: 'BREAST'
# (0018,1000) Device Serial Number                LO: '106974'
# (0018,1020) Software Versions                   LO: ['Raffaello 4.12.17.0', 'CANOVA 4.14.17.0', 'IMSTomoProc 4.3.2 (WL)', '(Proj. Raffaello 4.12.17.0 - IMSProc 4.12.16.0)']
# (0018,1030) Protocol Name                       LO: 'Mammography'
# (0018,1200) Date of Last Calibration            DA: '20220412'
# (0018,9004) Content Qualification               CS: 'PRODUCT'
# (0018,9506)  Contributing Sources Sequence  1 item(s) ----
#    (0008,002A) Acquisition DateTime                DT: '20220412155800'
#    (0008,0070) Manufacturer                        LO: 'IMS GIOTTO S.p.A.'
#    (0008,1010) Station Name                        SH: 'GIOTTO CLASS'
#    (0008,1090) Manufacturer's Model Name           LO: 'GIOTTO CLASS'
#    (0018,1000) Device Serial Number                LO: '106974'
#    (0018,1020) Software Versions                   LO: 'Raffaello 4.12.17.0 - IMSProc 4.12.16.0'
#    (0018,1030) Protocol Name                       LO: 'Mammography'
#    (0018,7004) Detector Type                       CS: 'DIRECT'
#    (0018,700A) Detector ID                         SH: 'AP01-31169'
#    (0018,700C) Date of Last Detector Calibration   DA: '20220412'
#    (0018,700E) Time of Last Detector Calibration   TM: '000000'
#    (0018,7022) Detector Element Spacing            DS: [0.085000, 0.085000]
#    (0020,9529)  Contributing SOP Instances Reference Sequence  1 item(s) ----
#       (0008,1115)  Referenced Series Sequence  1 item(s) ----
#          (0008,114A)  Referenced Instance Sequence  11 item(s) ----
#             (0008,1150) Referenced SOP Class UID            UI: Digital Mammography X-Ray Image Storage - For Processing
#             (0008,1155) Referenced SOP Instance UID         UI: 2.16.840.1.113669.632.25.1.106974.20220412155800521.1.3.5
#             (0020,0013) Instance Number                     IS: '1'
#             ---------
#             (0008,1150) Referenced SOP Class UID            UI: Digital Mammography X-Ray Image Storage - For Processing
#             (0008,1155) Referenced SOP Instance UID         UI: 2.16.840.1.113669.632.25.1.106974.20220412155802662.2.3.5
#             (0020,0013) Instance Number                     IS: '2'
#             ---------
#             (0008,1150) Referenced SOP Class UID            UI: Digital Mammography X-Ray Image Storage - For Processing
#             (0008,1155) Referenced SOP Instance UID         UI: 2.16.840.1.113669.632.25.1.106974.20220412155803589.3.3.5
#             (0020,0013) Instance Number                     IS: '3'
#             ---------
#             (0008,1150) Referenced SOP Class UID            UI: Digital Mammography X-Ray Image Storage - For Processing
#             (0008,1155) Referenced SOP Instance UID         UI: 2.16.840.1.113669.632.25.1.106974.20220412155804438.4.3.5
#             (0020,0013) Instance Number                     IS: '4'
#             ---------
#             (0008,1150) Referenced SOP Class UID            UI: Digital Mammography X-Ray Image Storage - For Processing
#             (0008,1155) Referenced SOP Instance UID         UI: 2.16.840.1.113669.632.25.1.106974.20220412155805322.5.3.5
#             (0020,0013) Instance Number                     IS: '5'
#             ---------
#             (0008,1150) Referenced SOP Class UID            UI: Digital Mammography X-Ray Image Storage - For Processing
#             (0008,1155) Referenced SOP Instance UID         UI: 2.16.840.1.113669.632.25.1.106974.20220412155807142.7.3.5
#             (0020,0013) Instance Number                     IS: '7'
#             ---------
#             (0008,1150) Referenced SOP Class UID            UI: Digital Mammography X-Ray Image Storage - For Processing
#             (0008,1155) Referenced SOP Instance UID         UI: 2.16.840.1.113669.632.25.1.106974.20220412155808321.8.3.5
#             (0020,0013) Instance Number                     IS: '8'
#             ---------
#             (0008,1150) Referenced SOP Class UID            UI: Digital Mammography X-Ray Image Storage - For Processing
#             (0008,1155) Referenced SOP Instance UID         UI: 2.16.840.1.113669.632.25.1.106974.20220412155808958.9.3.5
#             (0020,0013) Instance Number                     IS: '9'
#             ---------
#             (0008,1150) Referenced SOP Class UID            UI: Digital Mammography X-Ray Image Storage - For Processing
#             (0008,1155) Referenced SOP Instance UID         UI: 2.16.840.1.113669.632.25.1.106974.20220412155809933.10.3.5
#             (0020,0013) Instance Number                     IS: '10'
#             ---------
#             (0008,1150) Referenced SOP Class UID            UI: Digital Mammography X-Ray Image Storage - For Processing
#             (0008,1155) Referenced SOP Instance UID         UI: 2.16.840.1.113669.632.25.1.106974.20220412155810881.11.3.5
#             (0020,0013) Instance Number                     IS: '11'
#             ---------
#             (0008,1150) Referenced SOP Class UID            UI: Digital Mammography X-Ray Image Storage - For Processing
#             (0008,1155) Referenced SOP Instance UID         UI: 2.16.840.1.113669.632.25.1.106974.20220412155806303.6.3.5
#             (0020,0013) Instance Number                     IS: '6'
#             ---------
#          (0020,000E) Series Instance UID                 UI: 2.16.840.1.113669.632.25.1.106974.20220412155800454.2.5
#          (0020,0011) Series Number                       IS: '5'
#          ---------
#       (0020,000D) Study Instance UID                  UI: 2.16.840.1.113669.632.25.1.106974.20220412155257288.1
#       ---------
#    (0028,0010) Rows                                US: 3580
#    (0028,0011) Columns                             US: 2812
#    (0028,0101) Bits Stored                         US: 13
#    (0028,2110) Lossy Image Compression             CS: '00'
#    ---------
# (0018,9507)  X-Ray 3D Acquisition Sequence  1 item(s) ----
#    (0008,2112)  Source Image Sequence  11 item(s) ----
#       (0008,1150) Referenced SOP Class UID            UI: Digital Mammography X-Ray Image Storage - For Processing
#       (0008,1155) Referenced SOP Instance UID         UI: 2.16.840.1.113669.632.25.1.106974.20220412155800521.1.3.5
#       ---------
#       (0008,1150) Referenced SOP Class UID            UI: Digital Mammography X-Ray Image Storage - For Processing
#       (0008,1155) Referenced SOP Instance UID         UI: 2.16.840.1.113669.632.25.1.106974.20220412155802662.2.3.5
#       ---------
#       (0008,1150) Referenced SOP Class UID            UI: Digital Mammography X-Ray Image Storage - For Processing
#       (0008,1155) Referenced SOP Instance UID         UI: 2.16.840.1.113669.632.25.1.106974.20220412155803589.3.3.5
#       ---------
#       (0008,1150) Referenced SOP Class UID            UI: Digital Mammography X-Ray Image Storage - For Processing
#       (0008,1155) Referenced SOP Instance UID         UI: 2.16.840.1.113669.632.25.1.106974.20220412155804438.4.3.5
#       ---------
#       (0008,1150) Referenced SOP Class UID            UI: Digital Mammography X-Ray Image Storage - For Processing
#       (0008,1155) Referenced SOP Instance UID         UI: 2.16.840.1.113669.632.25.1.106974.20220412155805322.5.3.5
#       ---------
#       (0008,1150) Referenced SOP Class UID            UI: Digital Mammography X-Ray Image Storage - For Processing
#       (0008,1155) Referenced SOP Instance UID         UI: 2.16.840.1.113669.632.25.1.106974.20220412155807142.7.3.5
#       ---------
#       (0008,1150) Referenced SOP Class UID            UI: Digital Mammography X-Ray Image Storage - For Processing
#       (0008,1155) Referenced SOP Instance UID         UI: 2.16.840.1.113669.632.25.1.106974.20220412155808321.8.3.5
#       ---------
#       (0008,1150) Referenced SOP Class UID            UI: Digital Mammography X-Ray Image Storage - For Processing
#       (0008,1155) Referenced SOP Instance UID         UI: 2.16.840.1.113669.632.25.1.106974.20220412155808958.9.3.5
#       ---------
#       (0008,1150) Referenced SOP Class UID            UI: Digital Mammography X-Ray Image Storage - For Processing
#       (0008,1155) Referenced SOP Instance UID         UI: 2.16.840.1.113669.632.25.1.106974.20220412155809933.10.3.5
#       ---------
#       (0008,1150) Referenced SOP Class UID            UI: Digital Mammography X-Ray Image Storage - For Processing
#       (0008,1155) Referenced SOP Instance UID         UI: 2.16.840.1.113669.632.25.1.106974.20220412155810881.11.3.5
#       ---------
#       (0008,1150) Referenced SOP Class UID            UI: Digital Mammography X-Ray Image Storage - For Processing
#       (0008,1155) Referenced SOP Instance UID         UI: 2.16.840.1.113669.632.25.1.106974.20220412155806303.6.3.5
#       ---------
#    (0018,0060) KVP                                 DS: '31'
#    (0018,1110) Distance Source to Detector         DS: '685.5'
#    (0018,1111) Distance Source to Patient          DS: '666.0'
#    (0018,1114) Estimated Radiographic Magnificatio DS: '1.0'
#    (0018,1147) Field of View Shape                 CS: 'RECTANGLE'
#    (0018,1160) Filter Type                         SH: 'STRIP'
#    (0018,1166) Grid                                CS: 'NONE'
#    (0018,1190) Focal Spot(s)                       DS: '0.3'
#    (0018,1191) Anode Target Material               CS: 'TUNGSTEN'
#    (0018,11A0) Body Part Thickness                 DS: '60.0'
#    (0018,11A2) Compression Force                   DS: '49.0'
#    (0018,11A4) Paddle Description                  LO: '24x30 TOMO'
#    (0018,7001) Detector Temperature                DS: '36.4'
#    (0018,7030) Field of View Origin                DS: [0, 0]
#    (0018,7050) Filter Material                     CS: 'SILVER'
#    (0018,7052) Filter Thickness Minimum            DS: '0.05'
#    (0018,7054) Filter Thickness Maximum            DS: '0.05'
#    (0018,7060) Exposure Control Mode               CS: 'AUTOMATIC'
#    (0018,7062) Exposure Control Mode Description   LT: Array of 153 elements
#    (0018,9328) Exposure Time in ms                 FD: 1064.0
#    (0018,9330) X-Ray Tube Current in mA            FD: 154.4
#    (0018,9332) Exposure in mAs                     FD: 164.93
#    (0018,9402) Distance Source to Isocenter        FL: 646.0
#    (0018,9420) X-Ray Receptor Type                 CS: 'DIGITAL_DETECTOR'
#    (0018,9461) Field of View Dimension(s) in Float FL: [296.0, 232.0]
#    (0018,9508) Primary Positioner Scan Arc         FL: 0.0
#    (0018,9510) Primary Positioner Scan Start Angle FL: -13.675682067871094
#    (0018,9516) Start Acquisition DateTime          DT: '20220412155800'
#    (0018,9517) End Acquisition DateTime            DT: '20220412155810'
#    (0018,9538)  Per Projection Acquisition Sequence  11 item(s) ----
#       (0008,3010) Irradiation Event UID               UI: 2.16.840.1.113669.632.25.1.106974.20220412155800487.8
#       (0018,0060) KVP                                 DS: '31'
#       (0018,1405) Relative X-Ray Exposure             IS: '6511'
#       (0018,1510) Positioner Primary Angle            DS: '-13.675682'
#       (0018,1511) Positioner Secondary Angle          DS: '0'
#       (0018,9328) Exposure Time in ms                 FD: 58.0
#       (0018,9330) X-Ray Tube Current in mA            FD: 154.0
#       (0018,9332) Exposure in mAs                     FD: 9.01
#       (0040,0316) Organ Dose                          DS: '0.00176'
#       (0040,8302) Entrance Dose in mGy                DS: '0.599'
#       (0040,8303) Entrance Dose Derivation            CS: 'IAK'
#       ---------
#       (0008,3010) Irradiation Event UID               UI: 2.16.840.1.113669.632.25.1.106974.20220412155800487.8
#       (0018,0060) KVP                                 DS: '31'
#       (0018,1405) Relative X-Ray Exposure             IS: '7836'
#       (0018,1510) Positioner Primary Angle            DS: '-10.942934'
#       (0018,1511) Positioner Secondary Angle          DS: '0'
#       (0018,9328) Exposure Time in ms                 FD: 100.0
#       (0018,9330) X-Ray Tube Current in mA            FD: 154.0
#       (0018,9332) Exposure in mAs                     FD: 15.54
#       (0040,0316) Organ Dose                          DS: '0.00306'
#       (0040,8302) Entrance Dose in mGy                DS: '1.031'
#       (0040,8303) Entrance Dose Derivation            CS: 'IAK'
#       ---------
#       (0008,3010) Irradiation Event UID               UI: 2.16.840.1.113669.632.25.1.106974.20220412155800487.8
#       (0018,0060) KVP                                 DS: '31'
#       (0018,1405) Relative X-Ray Exposure             IS: '7859'
#       (0018,1510) Positioner Primary Angle            DS: '-8.188035'
#       (0018,1511) Positioner Secondary Angle          DS: '0'
#       (0018,9328) Exposure Time in ms                 FD: 101.0
#       (0018,9330) X-Ray Tube Current in mA            FD: 154.0
#       (0018,9332) Exposure in mAs                     FD: 15.61
#       (0040,0316) Organ Dose                          DS: '0.00311'
#       (0040,8302) Entrance Dose in mGy                DS: '1.036'
#       (0040,8303) Entrance Dose Derivation            CS: 'IAK'
#       ---------
#       (0008,3010) Irradiation Event UID               UI: 2.16.840.1.113669.632.25.1.106974.20220412155800487.8
#       (0018,0060) KVP                                 DS: '31'
#       (0018,1405) Relative X-Ray Exposure             IS: '7872'
#       (0018,1510) Positioner Primary Angle            DS: '-5.454013'
#       (0018,1511) Positioner Secondary Angle          DS: '0'
#       (0018,9328) Exposure Time in ms                 FD: 100.0
#       (0018,9330) X-Ray Tube Current in mA            FD: 154.0
#       (0018,9332) Exposure in mAs                     FD: 15.53
#       (0040,0316) Organ Dose                          DS: '0.00311'
#       (0040,8302) Entrance Dose in mGy                DS: '1.031'
#       (0040,8303) Entrance Dose Derivation            CS: 'IAK'
#       ---------
#       (0008,3010) Irradiation Event UID               UI: 2.16.840.1.113669.632.25.1.106974.20220412155800487.8
#       (0018,0060) KVP                                 DS: '31'
#       (0018,1405) Relative X-Ray Exposure             IS: '7883'
#       (0018,1510) Positioner Primary Angle            DS: '-2.720703'
#       (0018,1511) Positioner Secondary Angle          DS: '0'
#       (0018,9328) Exposure Time in ms                 FD: 101.0
#       (0018,9330) X-Ray Tube Current in mA            FD: 154.0
#       (0018,9332) Exposure in mAs                     FD: 15.61
#       (0040,0316) Organ Dose                          DS: '0.00314'
#       (0040,8302) Entrance Dose in mGy                DS: '1.036'
#       (0040,8303) Entrance Dose Derivation            CS: 'IAK'
#       ---------
#       (0008,3010) Irradiation Event UID               UI: 2.16.840.1.113669.632.25.1.106974.20220412155800487.8
#       (0018,0060) KVP                                 DS: '31'
#       (0018,1405) Relative X-Ray Exposure             IS: '7890'
#       (0018,1510) Positioner Primary Angle            DS: '2.74238'
#       (0018,1511) Positioner Secondary Angle          DS: '0'
#       (0018,9328) Exposure Time in ms                 FD: 101.0
#       (0018,9330) X-Ray Tube Current in mA            FD: 154.0
#       (0018,9332) Exposure in mAs                     FD: 15.6
#       (0040,0316) Organ Dose                          DS: '0.00314'
#       (0040,8302) Entrance Dose in mGy                DS: '1.035'
#       (0040,8303) Entrance Dose Derivation            CS: 'IAK'
#       ---------
#       (0008,3010) Irradiation Event UID               UI: 2.16.840.1.113669.632.25.1.106974.20220412155800487.8
#       (0018,0060) KVP                                 DS: '31'
#       (0018,1405) Relative X-Ray Exposure             IS: '7886'
#       (0018,1510) Positioner Primary Angle            DS: '5.476636'
#       (0018,1511) Positioner Secondary Angle          DS: '0'
#       (0018,9328) Exposure Time in ms                 FD: 101.0
#       (0018,9330) X-Ray Tube Current in mA            FD: 154.0
#       (0018,9332) Exposure in mAs                     FD: 15.66
#       (0040,0316) Organ Dose                          DS: '0.00314'
#       (0040,8302) Entrance Dose in mGy                DS: '1.039'
#       (0040,8303) Entrance Dose Derivation            CS: 'IAK'
#       ---------
#       (0008,3010) Irradiation Event UID               UI: 2.16.840.1.113669.632.25.1.106974.20220412155800487.8
#       (0018,0060) KVP                                 DS: '31'
#       (0018,1405) Relative X-Ray Exposure             IS: '7878'
#       (0018,1510) Positioner Primary Angle            DS: '8.210665'
#       (0018,1511) Positioner Secondary Angle          DS: '0'
#       (0018,9328) Exposure Time in ms                 FD: 101.0
#       (0018,9330) X-Ray Tube Current in mA            FD: 154.0
#       (0018,9332) Exposure in mAs                     FD: 15.65
#       (0040,0316) Organ Dose                          DS: '0.00311'
#       (0040,8302) Entrance Dose in mGy                DS: '1.039'
#       (0040,8303) Entrance Dose Derivation            CS: 'IAK'
#       ---------
#       (0008,3010) Irradiation Event UID               UI: 2.16.840.1.113669.632.25.1.106974.20220412155800487.8
#       (0018,0060) KVP                                 DS: '31'
#       (0018,1405) Relative X-Ray Exposure             IS: '7855'
#       (0018,1510) Positioner Primary Angle            DS: '10.940104'
#       (0018,1511) Positioner Secondary Angle          DS: '0'
#       (0018,9328) Exposure Time in ms                 FD: 101.0
#       (0018,9330) X-Ray Tube Current in mA            FD: 154.0
#       (0018,9332) Exposure in mAs                     FD: 15.64
#       (0040,0316) Organ Dose                          DS: '0.00308'
#       (0040,8302) Entrance Dose in mGy                DS: '1.038'
#       (0040,8303) Entrance Dose Derivation            CS: 'IAK'
#       ---------
#       (0008,3010) Irradiation Event UID               UI: 2.16.840.1.113669.632.25.1.106974.20220412155800487.8
#       (0018,0060) KVP                                 DS: '31'
#       (0018,1405) Relative X-Ray Exposure             IS: '7707'
#       (0018,1510) Positioner Primary Angle            DS: '13.678514'
#       (0018,1511) Positioner Secondary Angle          DS: '0'
#       (0018,9328) Exposure Time in ms                 FD: 100.0
#       (0018,9330) X-Ray Tube Current in mA            FD: 154.0
#       (0018,9332) Exposure in mAs                     FD: 15.56
#       (0040,0316) Organ Dose                          DS: '0.00303'
#       (0040,8302) Entrance Dose in mGy                DS: '1.033'
#       (0040,8303) Entrance Dose Derivation            CS: 'IAK'
#       ---------
#       (0008,3010) Irradiation Event UID               UI: 2.16.840.1.113669.632.25.1.106974.20220412155800487.8
#       (0018,0060) KVP                                 DS: '31'
#       (0018,1405) Relative X-Ray Exposure             IS: '7888'
#       (0018,1510) Positioner Primary Angle            DS: '0.00377'
#       (0018,1511) Positioner Secondary Angle          DS: '0'
#       (0018,9328) Exposure Time in ms                 FD: 100.0
#       (0018,9330) X-Ray Tube Current in mA            FD: 154.0
#       (0018,9332) Exposure in mAs                     FD: 15.52
#       (0040,0316) Organ Dose                          DS: '0.00313'
#       (0040,8302) Entrance Dose in mGy                DS: '1.03'
#       (0040,8303) Entrance Dose Derivation            CS: 'IAK'
#       ---------
#    (0040,0314) Half Value Layer                    DS: '0.583'
#    (0040,0316) Organ Dose                          DS: '0.03281'
#    (0040,8302) Entrance Dose in mGy                DS: '10.947'
#    (0040,8303) Entrance Dose Derivation            CS: 'IAK'
#    ---------
# (0018,9530)  X-Ray 3D Reconstruction Sequence  1 item(s) ----
#    (0018,9524) Application Name                    LO: 'Canova'
#    (0018,9525) Application Version                 LO: 'CANOVA 4.14.17.0 - IMSTomoProc 4.3.2 (WL)'
#    (0018,9526) Application Manufacturer            LO: 'IMS GIOTTO S.p.A.'
#    (0018,9527) Algorithm Type                      CS: 'ITERATIVE'
#    (0020,9518) Acquisition Index                   US: 1
#    ---------
# (0020,000D) Study Instance UID                  UI: 2.16.840.1.113669.632.25.1.106974.20220412155257288.1
# (0020,000E) Series Instance UID                 UI: 2.16.840.1.113669.632.25.1.106974.20220502080359669.2.9
# (0020,0010) Study ID                            SH: '166'
# (0020,0011) Series Number                       IS: '5'
# (0020,0013) Instance Number                     IS: '1'
# (0020,0020) Patient Orientation                 CS: ['P', 'L']
# (0020,0052) Frame of Reference UID              UI: 2.16.840.1.113669.632.25.1.106974.20220412155800476.6
# (0020,1040) Position Reference Indicator        LO: ''
# (0028,0002) Samples per Pixel                   US: 1
# (0028,0004) Photometric Interpretation          CS: 'MONOCHROME2'
# (0028,0008) Number of Frames                    IS: '64'
# (0028,0010) Rows                                US: 2258
# (0028,0011) Columns                             US: 1184
# (0028,0100) Bits Allocated                      US: 16
# (0028,0101) Bits Stored                         US: 14
# (0028,0102) High Bit                            US: 13
# (0028,0103) Pixel Representation                US: 0
# (0028,0120) Pixel Padding Value                 US: 0
# (0028,0121) Pixel Padding Range Limit           US: 0
# (0028,0300) Quality Control Image               CS: 'YES'
# (0028,0301) Burned In Annotation                CS: 'NO'
# (0028,1300) Breast Implant Present              CS: 'NO'
# (0028,1350) Partial View                        CS: 'NO'
# (0028,2110) Lossy Image Compression             CS: '00'
# (0040,0244) Performed Procedure Step Start Date DA: '20220412'
# (0040,0245) Performed Procedure Step Start Time TM: '155257'
# (0040,0253) Performed Procedure Step ID         SH: '20210916'
# (0040,0254) Performed Procedure Step Descriptio LO: ''
# (0040,0316) Organ Dose                          DS: '0.03281'
# (0040,0555)  Acquisition Context Sequence  0 item(s) ----
# (0040,8302) Entrance Dose in mGy                DS: '10.947'
# (0054,0220)  View Code Sequence  1 item(s) ----
#    (0008,0100) Code Value                          SH: 'R-10242'
#    (0008,0102) Coding Scheme Designator            SH: 'SRT'
#    (0008,0104) Code Meaning                        LO: 'cranio-caudal'
#    (0054,0222)  View Modifier Code Sequence  0 item(s) ----
#    ---------
# (1269,0010) Private Creator                     LO: 'Raffaello Biopsy Private Code'
# (1269,1001) Private tag data                    IS: '0'
# (1271,0010) Private Creator                     LO: 'Raffaello Mammography Private Code'
# (1271,1010) Private tag data                    IS: '0'
# (1271,1011) Private tag data                    IS: '1184'
# (1271,1012) Private tag data                    IS: '0'
# (1271,1013) Private tag data                    IS: '2258'
# (1271,1025) Private tag data                    IS: '0'
# (1271,1042) Private tag data                    LT: Array of 1778 elements
# (1271,1081) Private tag data                    IS: '1'
# (1271,1085) Private tag data                    IS: '0'
# (1271,1086) Private tag data                    LT: Array of 74 elements
# (1271,1091) Private tag data                    LO: '1.4'
# (1271,1092) Private tag data                    LT: Array of 263 elements
# (1271,1096) Private tag data                    IS: '0'
# (1271,10A1) Private tag data                    US: 0
# (2050,0020) Presentation LUT Shape              CS: 'IDENTITY'
# (5200,9229)  Shared Functional Groups Sequence  1 item(s) ----
#    (0008,9124)  Derivation Image Sequence  1 item(s) ----
#       (0008,2112)  Source Image Sequence  11 item(s) ----
#          (0008,1150) Referenced SOP Class UID            UI: Digital Mammography X-Ray Image Storage - For Processing
#          (0008,1155) Referenced SOP Instance UID         UI: 2.16.840.1.113669.632.25.1.106974.20220412155800521.1.3.5
#          (0040,A170)  Purpose of Reference Code Sequence  1 item(s) ----
#             (0008,0100) Code Value                          SH: '121322'
#             (0008,0102) Coding Scheme Designator            SH: 'DCM'
#             (0008,0104) Code Meaning                        LO: 'Source image for image processing operation'
#             ---------
#          ---------
#          (0008,1150) Referenced SOP Class UID            UI: Digital Mammography X-Ray Image Storage - For Processing
#          (0008,1155) Referenced SOP Instance UID         UI: 2.16.840.1.113669.632.25.1.106974.20220412155802662.2.3.5
#          (0040,A170)  Purpose of Reference Code Sequence  1 item(s) ----
#             (0008,0100) Code Value                          SH: '121322'
#             (0008,0102) Coding Scheme Designator            SH: 'DCM'
#             (0008,0104) Code Meaning                        LO: 'Source image for image processing operation'
#             ---------
#          ---------
#          (0008,1150) Referenced SOP Class UID            UI: Digital Mammography X-Ray Image Storage - For Processing
#          (0008,1155) Referenced SOP Instance UID         UI: 2.16.840.1.113669.632.25.1.106974.20220412155803589.3.3.5
#          (0040,A170)  Purpose of Reference Code Sequence  1 item(s) ----
#             (0008,0100) Code Value                          SH: '121322'
#             (0008,0102) Coding Scheme Designator            SH: 'DCM'
#             (0008,0104) Code Meaning                        LO: 'Source image for image processing operation'
#             ---------
#          ---------
#          (0008,1150) Referenced SOP Class UID            UI: Digital Mammography X-Ray Image Storage - For Processing
#          (0008,1155) Referenced SOP Instance UID         UI: 2.16.840.1.113669.632.25.1.106974.20220412155804438.4.3.5
#          (0040,A170)  Purpose of Reference Code Sequence  1 item(s) ----
#             (0008,0100) Code Value                          SH: '121322'
#             (0008,0102) Coding Scheme Designator            SH: 'DCM'
#             (0008,0104) Code Meaning                        LO: 'Source image for image processing operation'
#             ---------
#          ---------
#          (0008,1150) Referenced SOP Class UID            UI: Digital Mammography X-Ray Image Storage - For Processing
#          (0008,1155) Referenced SOP Instance UID         UI: 2.16.840.1.113669.632.25.1.106974.20220412155805322.5.3.5
#          (0040,A170)  Purpose of Reference Code Sequence  1 item(s) ----
#             (0008,0100) Code Value                          SH: '121322'
#             (0008,0102) Coding Scheme Designator            SH: 'DCM'
#             (0008,0104) Code Meaning                        LO: 'Source image for image processing operation'
#             ---------
#          ---------
#          (0008,1150) Referenced SOP Class UID            UI: Digital Mammography X-Ray Image Storage - For Processing
#          (0008,1155) Referenced SOP Instance UID         UI: 2.16.840.1.113669.632.25.1.106974.20220412155807142.7.3.5
#          (0040,A170)  Purpose of Reference Code Sequence  1 item(s) ----
#             (0008,0100) Code Value                          SH: '121322'
#             (0008,0102) Coding Scheme Designator            SH: 'DCM'
#             (0008,0104) Code Meaning                        LO: 'Source image for image processing operation'
#             ---------
#          ---------
#          (0008,1150) Referenced SOP Class UID            UI: Digital Mammography X-Ray Image Storage - For Processing
#          (0008,1155) Referenced SOP Instance UID         UI: 2.16.840.1.113669.632.25.1.106974.20220412155808321.8.3.5
#          (0040,A170)  Purpose of Reference Code Sequence  1 item(s) ----
#             (0008,0100) Code Value                          SH: '121322'
#             (0008,0102) Coding Scheme Designator            SH: 'DCM'
#             (0008,0104) Code Meaning                        LO: 'Source image for image processing operation'
#             ---------
#          ---------
#          (0008,1150) Referenced SOP Class UID            UI: Digital Mammography X-Ray Image Storage - For Processing
#          (0008,1155) Referenced SOP Instance UID         UI: 2.16.840.1.113669.632.25.1.106974.20220412155808958.9.3.5
#          (0040,A170)  Purpose of Reference Code Sequence  1 item(s) ----
#             (0008,0100) Code Value                          SH: '121322'
#             (0008,0102) Coding Scheme Designator            SH: 'DCM'
#             (0008,0104) Code Meaning                        LO: 'Source image for image processing operation'
#             ---------
#          ---------
#          (0008,1150) Referenced SOP Class UID            UI: Digital Mammography X-Ray Image Storage - For Processing
#          (0008,1155) Referenced SOP Instance UID         UI: 2.16.840.1.113669.632.25.1.106974.20220412155809933.10.3.5
#          (0040,A170)  Purpose of Reference Code Sequence  1 item(s) ----
#             (0008,0100) Code Value                          SH: '121322'
#             (0008,0102) Coding Scheme Designator            SH: 'DCM'
#             (0008,0104) Code Meaning                        LO: 'Source image for image processing operation'
#             ---------
#          ---------
#          (0008,1150) Referenced SOP Class UID            UI: Digital Mammography X-Ray Image Storage - For Processing
#          (0008,1155) Referenced SOP Instance UID         UI: 2.16.840.1.113669.632.25.1.106974.20220412155810881.11.3.5
#          (0040,A170)  Purpose of Reference Code Sequence  1 item(s) ----
#             (0008,0100) Code Value                          SH: '121322'
#             (0008,0102) Coding Scheme Designator            SH: 'DCM'
#             (0008,0104) Code Meaning                        LO: 'Source image for image processing operation'
#             ---------
#          ---------
#          (0008,1150) Referenced SOP Class UID            UI: Digital Mammography X-Ray Image Storage - For Processing
#          (0008,1155) Referenced SOP Instance UID         UI: 2.16.840.1.113669.632.25.1.106974.20220412155806303.6.3.5
#          (0040,A170)  Purpose of Reference Code Sequence  1 item(s) ----
#             (0008,0100) Code Value                          SH: '121322'
#             (0008,0102) Coding Scheme Designator            SH: 'DCM'
#             (0008,0104) Code Meaning                        LO: 'Source image for image processing operation'
#             ---------
#          ---------
#       (0008,9215)  Derivation Code Sequence  1 item(s) ----
#          (0008,0100) Code Value                          SH: '113074'
#          (0008,0102) Coding Scheme Designator            SH: 'DCM'
#          (0008,0104) Code Meaning                        LO: 'Volume rendering'
#          ---------
#       ---------
#    (0020,9071)  Frame Anatomy Sequence  1 item(s) ----
#       (0008,2218)  Anatomic Region Sequence  1 item(s) ----
#          (0008,0100) Code Value                          SH: 'T-04000'
#          (0008,0102) Coding Scheme Designator            SH: 'SRT'
#          (0008,0104) Code Meaning                        LO: 'Breast'
#          ---------
#       (0020,9072) Frame Laterality                    CS: 'R'
#       ---------
#    (0020,9116)  Plane Orientation Sequence  1 item(s) ----
#       (0020,0037) Image Orientation (Patient)         DS: [0.0000, 1.0000, 0.0000, 1.0000, 0.0000, 0.0000]
#       ---------
#    (0028,9110)  Pixel Measures Sequence  1 item(s) ----
#       (0018,0050) Slice Thickness                     DS: '1.000000'
#       (0028,0030) Pixel Spacing                       DS: [0.090100, 0.090100]
#       ---------
#    (0028,9132)  Frame VOI LUT Sequence  1 item(s) ----
#       (0028,1050) Window Center                       DS: [4432, 4432, 4432, 4403, 4432]
#       (0028,1051) Window Width                        DS: [1417, 1417, 1558, 1275, 1417]
#       (0028,1055) Window Center & Width Explanation   LO: ['CURRENT', 'STANDARD', 'SMOOTH', 'CONTRAST', 'CUSTOM']
#       (0028,1056) VOI LUT Function                    CS: 'LINEAR'
#       ---------
#    (0028,9145)  Pixel Value Transformation Sequence  1 item(s) ----
#       (0028,1052) Rescale Intercept                   DS: '0'
#       (0028,1053) Rescale Slope                       DS: '1'
#       (0028,1054) Rescale Type                        LO: 'US'
#       ---------
#    ---------
# (5200,9230)  Per-Frame Functional Groups Sequence  64 item(s) ----
#    (0018,9504)  X-Ray 3D Frame Type Sequence  1 item(s) ----
#       (0008,9007) Frame Type                          CS: ['DERIVED', 'PRIMARY', 'TOMOSYNTHESIS', 'NONE']
#       (0008,9205) Pixel Presentation                  CS: 'MONOCHROME'
#       (0008,9206) Volumetric Properties               CS: 'VOLUME'
#       (0008,9207) Volume Based Calculation Technique  CS: 'NONE'
#       (0020,9536) Reconstruction Index                US: 1
#       ---------
#    (0020,9111)  Frame Content Sequence  1 item(s) ----
#
#       ---------
#    (0020,9113)  Plane Position Sequence  1 item(s) ----
#       (0020,0032) Image Position (Patient)            DS: [-84.1245, -106.7583, 0.0000]
#       ---------
#    ---------
#    (0018,9504)  X-Ray 3D Frame Type Sequence  1 item(s) ----
#       (0008,9007) Frame Type                          CS: ['DERIVED', 'PRIMARY', 'TOMOSYNTHESIS', 'NONE']
#       (0008,9205) Pixel Presentation                  CS: 'MONOCHROME'
#       (0008,9206) Volumetric Properties               CS: 'VOLUME'
#       (0008,9207) Volume Based Calculation Technique  CS: 'NONE'
#       (0020,9536) Reconstruction Index                US: 1
#       ---------
#    (0020,9111)  Frame Content Sequence  1 item(s) ----
#
#       ---------
#    (0020,9113)  Plane Position Sequence  1 item(s) ----
#       (0020,0032) Image Position (Patient)            DS: [-84.1245, -106.7583, 1.0000]
#       ---------
#    ---------
#    (0018,9504)  X-Ray 3D Frame Type Sequence  1 item(s) ----
#       (0008,9007) Frame Type                          CS: ['DERIVED', 'PRIMARY', 'TOMOSYNTHESIS', 'NONE']
#       (0008,9205) Pixel Presentation                  CS: 'MONOCHROME'
#       (0008,9206) Volumetric Properties               CS: 'VOLUME'
#       (0008,9207) Volume Based Calculation Technique  CS: 'NONE'
#       (0020,9536) Reconstruction Index                US: 1
#       ---------
#    (0020,9111)  Frame Content Sequence  1 item(s) ----
#
#       ---------
# ...
#       (0008,9205) Pixel Presentation                  CS: 'MONOCHROME'
#       (0008,9206) Volumetric Properties               CS: 'VOLUME'
#       (0008,9207) Volume Based Calculation Technique  CS: 'NONE'
#       (0020,9536) Reconstruction Index                US: 1
#       ---------
#    (0020,9111)  Frame Content Sequence  1 item(s) ----
#
#       ---------
#    (0020,9113)  Plane Position Sequence  1 item(s) ----
#       (0020,0032) Image Position (Patient)            DS: [-84.1245, -106.7583, 41.0000]
#       ---------
#    ---------
#    (0018,9504)  X-Ray 3D Frame Type Sequence  1 item(s) ----
#       (0008,9007) Frame Type                          CS: ['DERIVED', 'PRIMARY', 'TOMOSYNTHESIS', 'NONE']
#       (0008,9205) Pixel Presentation                  CS: 'MONOCHROME'
#       (0008,9206) Volumetric Properties               CS: 'VOLUME'
#       (0008,9207) Volume Based Calculation Technique  CS: 'NONE'
#       (0020,9536) Reconstruction Index                US: 1
#       ---------
#    (0020,9111)  Frame Content Sequence  1 item(s) ----
#
#       ---------
#    (0020,9113)  Plane Position Sequence  1 item(s) ----
#       (0020,0032) Image Position (Patient)            DS: [-84.1245, -106.7583, 42.0000]
#       ---------
#    ---------
#    (0018,9504)  X-Ray 3D Frame Type Sequence  1 item(s) ----
#       (0008,9007) Frame Type                          CS: ['DERIVED', 'PRIMARY', 'TOMOSYNTHESIS', 'NONE']
#       (0008,9205) Pixel Presentation                  CS: 'MONOCHROME'
#       (0008,9206) Volumetric Properties               CS: 'VOLUME'
#       (0008,9207) Volume Based Calculation Technique  CS: 'NONE'
#       (0020,9536) Reconstruction Index                US: 1
#       ---------
#    (0020,9111)  Frame Content Sequence  1 item(s) ----
#
#       ---------
#    (0020,9113)  Plane Position Sequence  1 item(s) ----
#       (0020,0032) Image Position (Patient)            DS: [-84.1245, -106.7583, 43.0000]
#       ---------
#    ---------
#    (0018,9504)  X-Ray 3D Frame Type Sequence  1 item(s) ----
#       (0008,9007) Frame Type                          CS: ['DERIVED', 'PRIMARY', 'TOMOSYNTHESIS', 'NONE']
#       (0008,9205) Pixel Presentation                  CS: 'MONOCHROME'
#       (0008,9206) Volumetric Properties               CS: 'VOLUME'
#       (0008,9207) Volume Based Calculation Technique  CS: 'NONE'
#       (0020,9536) Reconstruction Index                US: 1
#       ---------
#    (0020,9111)  Frame Content Sequence  1 item(s) ----
#
#       ---------
#    (0020,9113)  Plane Position Sequence  1 item(s) ----
#       (0020,0032) Image Position (Patient)            DS: [-84.1245, -106.7583, 44.0000]
#       ---------
#    ---------
#    (0018,9504)  X-Ray 3D Frame Type Sequence  1 item(s) ----
#       (0008,9007) Frame Type                          CS: ['DERIVED', 'PRIMARY', 'TOMOSYNTHESIS', 'NONE']
#       (0008,9205) Pixel Presentation                  CS: 'MONOCHROME'
#       (0008,9206) Volumetric Properties               CS: 'VOLUME'
#       (0008,9207) Volume Based Calculation Technique  CS: 'NONE'
#       (0020,9536) Reconstruction Index                US: 1
#       ---------
#    (0020,9111)  Frame Content Sequence  1 item(s) ----
#
#       ---------
#    (0020,9113)  Plane Position Sequence  1 item(s) ----
#       (0020,0032) Image Position (Patient)            DS: [-84.1245, -106.7583, 45.0000]
#       ---------
#    ---------
#    (0018,9504)  X-Ray 3D Frame Type Sequence  1 item(s) ----
#       (0008,9007) Frame Type                          CS: ['DERIVED', 'PRIMARY', 'TOMOSYNTHESIS', 'NONE']
#       (0008,9205) Pixel Presentation                  CS: 'MONOCHROME'
#       (0008,9206) Volumetric Properties               CS: 'VOLUME'
#       (0008,9207) Volume Based Calculation Technique  CS: 'NONE'
#       (0020,9536) Reconstruction Index                US: 1
#       ---------
#    (0020,9111)  Frame Content Sequence  1 item(s) ----
#
#       ---------
#    (0020,9113)  Plane Position Sequence  1 item(s) ----
#       (0020,0032) Image Position (Patient)            DS: [-84.1245, -106.7583, 46.0000]
#       ---------
#    ---------
#    (0018,9504)  X-Ray 3D Frame Type Sequence  1 item(s) ----
#       (0008,9007) Frame Type                          CS: ['DERIVED', 'PRIMARY', 'TOMOSYNTHESIS', 'NONE']
#       (0008,9205) Pixel Presentation                  CS: 'MONOCHROME'
#       (0008,9206) Volumetric Properties               CS: 'VOLUME'
#       (0008,9207) Volume Based Calculation Technique  CS: 'NONE'
#       (0020,9536) Reconstruction Index                US: 1
#       ---------
#    (0020,9111)  Frame Content Sequence  1 item(s) ----
#
#       ---------
#    (0020,9113)  Plane Position Sequence  1 item(s) ----
#       (0020,0032) Image Position (Patient)            DS: [-84.1245, -106.7583, 47.0000]
#       ---------
#    ---------
#    (0018,9504)  X-Ray 3D Frame Type Sequence  1 item(s) ----
#       (0008,9007) Frame Type                          CS: ['DERIVED', 'PRIMARY', 'TOMOSYNTHESIS', 'NONE']
#       (0008,9205) Pixel Presentation                  CS: 'MONOCHROME'
#       (0008,9206) Volumetric Properties               CS: 'VOLUME'
#       (0008,9207) Volume Based Calculation Technique  CS: 'NONE'
#       (0020,9536) Reconstruction Index                US: 1
#       ---------
#    (0020,9111)  Frame Content Sequence  1 item(s) ----
#
#       ---------
#    (0020,9113)  Plane Position Sequence  1 item(s) ----
#       (0020,0032) Image Position (Patient)            DS: [-84.1245, -106.7583, 48.0000]
#       ---------
#    ---------
#    (0018,9504)  X-Ray 3D Frame Type Sequence  1 item(s) ----
#       (0008,9007) Frame Type                          CS: ['DERIVED', 'PRIMARY', 'TOMOSYNTHESIS', 'NONE']
#       (0008,9205) Pixel Presentation                  CS: 'MONOCHROME'
#       (0008,9206) Volumetric Properties               CS: 'VOLUME'
#       (0008,9207) Volume Based Calculation Technique  CS: 'NONE'
#       (0020,9536) Reconstruction Index                US: 1
#       ---------
#    (0020,9111)  Frame Content Sequence  1 item(s) ----
#
#       ---------
#    (0020,9113)  Plane Position Sequence  1 item(s) ----
#       (0020,0032) Image Position (Patient)            DS: [-84.1245, -106.7583, 49.0000]
#       ---------
#    ---------
#    (0018,9504)  X-Ray 3D Frame Type Sequence  1 item(s) ----
#       (0008,9007) Frame Type                          CS: ['DERIVED', 'PRIMARY', 'TOMOSYNTHESIS', 'NONE']
#       (0008,9205) Pixel Presentation                  CS: 'MONOCHROME'
#       (0008,9206) Volumetric Properties               CS: 'VOLUME'
#       (0008,9207) Volume Based Calculation Technique  CS: 'NONE'
#       (0020,9536) Reconstruction Index                US: 1
#       ---------
#    (0020,9111)  Frame Content Sequence  1 item(s) ----
#
#       ---------
#    (0020,9113)  Plane Position Sequence  1 item(s) ----
#       (0020,0032) Image Position (Patient)            DS: [-84.1245, -106.7583, 50.0000]
#       ---------
#    ---------
#    (0018,9504)  X-Ray 3D Frame Type Sequence  1 item(s) ----
#       (0008,9007) Frame Type                          CS: ['DERIVED', 'PRIMARY', 'TOMOSYNTHESIS', 'NONE']
#       (0008,9205) Pixel Presentation                  CS: 'MONOCHROME'
#       (0008,9206) Volumetric Properties               CS: 'VOLUME'
#       (0008,9207) Volume Based Calculation Technique  CS: 'NONE'
#       (0020,9536) Reconstruction Index                US: 1
#       ---------
#    (0020,9111)  Frame Content Sequence  1 item(s) ----
#
#       ---------
#    (0020,9113)  Plane Position Sequence  1 item(s) ----
#       (0020,0032) Image Position (Patient)            DS: [-84.1245, -106.7583, 51.0000]
#       ---------
#    ---------
#    (0018,9504)  X-Ray 3D Frame Type Sequence  1 item(s) ----
#       (0008,9007) Frame Type                          CS: ['DERIVED', 'PRIMARY', 'TOMOSYNTHESIS', 'NONE']
#       (0008,9205) Pixel Presentation                  CS: 'MONOCHROME'
#       (0008,9206) Volumetric Properties               CS: 'VOLUME'
#       (0008,9207) Volume Based Calculation Technique  CS: 'NONE'
#       (0020,9536) Reconstruction Index                US: 1
#       ---------
#    (0020,9111)  Frame Content Sequence  1 item(s) ----
#
#       ---------
#    (0020,9113)  Plane Position Sequence  1 item(s) ----
#       (0020,0032) Image Position (Patient)            DS: [-84.1245, -106.7583, 52.0000]
#       ---------
#    ---------
#    (0018,9504)  X-Ray 3D Frame Type Sequence  1 item(s) ----
#       (0008,9007) Frame Type                          CS: ['DERIVED', 'PRIMARY', 'TOMOSYNTHESIS', 'NONE']
#       (0008,9205) Pixel Presentation                  CS: 'MONOCHROME'
#       (0008,9206) Volumetric Properties               CS: 'VOLUME'
#       (0008,9207) Volume Based Calculation Technique  CS: 'NONE'
#       (0020,9536) Reconstruction Index                US: 1
#       ---------
#    (0020,9111)  Frame Content Sequence  1 item(s) ----
#
#       ---------
#    (0020,9113)  Plane Position Sequence  1 item(s) ----
#       (0020,0032) Image Position (Patient)            DS: [-84.1245, -106.7583, 53.0000]
#       ---------
#    ---------
#    (0018,9504)  X-Ray 3D Frame Type Sequence  1 item(s) ----
#       (0008,9007) Frame Type                          CS: ['DERIVED', 'PRIMARY', 'TOMOSYNTHESIS', 'NONE']
#       (0008,9205) Pixel Presentation                  CS: 'MONOCHROME'
#       (0008,9206) Volumetric Properties               CS: 'VOLUME'
#       (0008,9207) Volume Based Calculation Technique  CS: 'NONE'
#       (0020,9536) Reconstruction Index                US: 1
#       ---------
#    (0020,9111)  Frame Content Sequence  1 item(s) ----
#
#       ---------
#    (0020,9113)  Plane Position Sequence  1 item(s) ----
#       (0020,0032) Image Position (Patient)            DS: [-84.1245, -106.7583, 54.0000]
#       ---------
#    ---------
#    (0018,9504)  X-Ray 3D Frame Type Sequence  1 item(s) ----
#       (0008,9007) Frame Type                          CS: ['DERIVED', 'PRIMARY', 'TOMOSYNTHESIS', 'NONE']
#       (0008,9205) Pixel Presentation                  CS: 'MONOCHROME'
#       (0008,9206) Volumetric Properties               CS: 'VOLUME'
#       (0008,9207) Volume Based Calculation Technique  CS: 'NONE'
#       (0020,9536) Reconstruction Index                US: 1
#       ---------
#    (0020,9111)  Frame Content Sequence  1 item(s) ----
#
#       ---------
#    (0020,9113)  Plane Position Sequence  1 item(s) ----
#       (0020,0032) Image Position (Patient)            DS: [-84.1245, -106.7583, 55.0000]
#       ---------
#    ---------
#    (0018,9504)  X-Ray 3D Frame Type Sequence  1 item(s) ----
#       (0008,9007) Frame Type                          CS: ['DERIVED', 'PRIMARY', 'TOMOSYNTHESIS', 'NONE']
#       (0008,9205) Pixel Presentation                  CS: 'MONOCHROME'
#       (0008,9206) Volumetric Properties               CS: 'VOLUME'
#       (0008,9207) Volume Based Calculation Technique  CS: 'NONE'
#       (0020,9536) Reconstruction Index                US: 1
#       ---------
#    (0020,9111)  Frame Content Sequence  1 item(s) ----
#
#       ---------
#    (0020,9113)  Plane Position Sequence  1 item(s) ----
#       (0020,0032) Image Position (Patient)            DS: [-84.1245, -106.7583, 56.0000]
#       ---------
#    ---------
#    (0018,9504)  X-Ray 3D Frame Type Sequence  1 item(s) ----
#       (0008,9007) Frame Type                          CS: ['DERIVED', 'PRIMARY', 'TOMOSYNTHESIS', 'NONE']
#       (0008,9205) Pixel Presentation                  CS: 'MONOCHROME'
#       (0008,9206) Volumetric Properties               CS: 'VOLUME'
#       (0008,9207) Volume Based Calculation Technique  CS: 'NONE'
#       (0020,9536) Reconstruction Index                US: 1
#       ---------
#    (0020,9111)  Frame Content Sequence  1 item(s) ----
#
#       ---------
#    (0020,9113)  Plane Position Sequence  1 item(s) ----
#       (0020,0032) Image Position (Patient)            DS: [-84.1245, -106.7583, 57.0000]
#       ---------
#    ---------
#    (0018,9504)  X-Ray 3D Frame Type Sequence  1 item(s) ----
#       (0008,9007) Frame Type                          CS: ['DERIVED', 'PRIMARY', 'TOMOSYNTHESIS', 'NONE']
#       (0008,9205) Pixel Presentation                  CS: 'MONOCHROME'
#       (0008,9206) Volumetric Properties               CS: 'VOLUME'
#       (0008,9207) Volume Based Calculation Technique  CS: 'NONE'
#       (0020,9536) Reconstruction Index                US: 1
#       ---------
#    (0020,9111)  Frame Content Sequence  1 item(s) ----
#
#       ---------
#    (0020,9113)  Plane Position Sequence  1 item(s) ----
#       (0020,0032) Image Position (Patient)            DS: [-84.1245, -106.7583, 58.0000]
#       ---------
#    ---------
#    (0018,9504)  X-Ray 3D Frame Type Sequence  1 item(s) ----
#       (0008,9007) Frame Type                          CS: ['DERIVED', 'PRIMARY', 'TOMOSYNTHESIS', 'NONE']
#       (0008,9205) Pixel Presentation                  CS: 'MONOCHROME'
#       (0008,9206) Volumetric Properties               CS: 'VOLUME'
#       (0008,9207) Volume Based Calculation Technique  CS: 'NONE'
#       (0020,9536) Reconstruction Index                US: 1
#       ---------
#    (0020,9111)  Frame Content Sequence  1 item(s) ----
#
#       ---------
#    (0020,9113)  Plane Position Sequence  1 item(s) ----
#       (0020,0032) Image Position (Patient)            DS: [-84.1245, -106.7583, 59.0000]
#       ---------
#    ---------
#    (0018,9504)  X-Ray 3D Frame Type Sequence  1 item(s) ----
#       (0008,9007) Frame Type                          CS: ['DERIVED', 'PRIMARY', 'TOMOSYNTHESIS', 'NONE']
#       (0008,9205) Pixel Presentation                  CS: 'MONOCHROME'
#       (0008,9206) Volumetric Properties               CS: 'VOLUME'
#       (0008,9207) Volume Based Calculation Technique  CS: 'NONE'
#       (0020,9536) Reconstruction Index                US: 1
#       ---------
#    (0020,9111)  Frame Content Sequence  1 item(s) ----
#
#       ---------
#    (0020,9113)  Plane Position Sequence  1 item(s) ----
#       (0020,0032) Image Position (Patient)            DS: [-84.1245, -106.7583, 60.0000]
#       ---------
#    ---------
#    (0018,9504)  X-Ray 3D Frame Type Sequence  1 item(s) ----
#       (0008,9007) Frame Type                          CS: ['DERIVED', 'PRIMARY', 'TOMOSYNTHESIS', 'NONE']
#       (0008,9205) Pixel Presentation                  CS: 'MONOCHROME'
#       (0008,9206) Volumetric Properties               CS: 'VOLUME'
#       (0008,9207) Volume Based Calculation Technique  CS: 'NONE'
#       (0020,9536) Reconstruction Index                US: 1
#       ---------
#    (0020,9111)  Frame Content Sequence  1 item(s) ----
#
#       ---------
#    (0020,9113)  Plane Position Sequence  1 item(s) ----
#       (0020,0032) Image Position (Patient)            DS: [-84.1245, -106.7583, 61.0000]
#       ---------
#    ---------
#    (0018,9504)  X-Ray 3D Frame Type Sequence  1 item(s) ----
#       (0008,9007) Frame Type                          CS: ['DERIVED', 'PRIMARY', 'TOMOSYNTHESIS', 'NONE']
#       (0008,9205) Pixel Presentation                  CS: 'MONOCHROME'
#       (0008,9206) Volumetric Properties               CS: 'VOLUME'
#       (0008,9207) Volume Based Calculation Technique  CS: 'NONE'
#       (0020,9536) Reconstruction Index                US: 1
#       ---------
#    (0020,9111)  Frame Content Sequence  1 item(s) ----
#
#       ---------
#    (0020,9113)  Plane Position Sequence  1 item(s) ----
#       (0020,0032) Image Position (Patient)            DS: [-84.1245, -106.7583, 62.0000]
#       ---------
#    ---------
#    (0018,9504)  X-Ray 3D Frame Type Sequence  1 item(s) ----
#       (0008,9007) Frame Type                          CS: ['DERIVED', 'PRIMARY', 'TOMOSYNTHESIS', 'NONE']
#       (0008,9205) Pixel Presentation                  CS: 'MONOCHROME'
#       (0008,9206) Volumetric Properties               CS: 'VOLUME'
#       (0008,9207) Volume Based Calculation Technique  CS: 'NONE'
#       (0020,9536) Reconstruction Index                US: 1
#       ---------
#    (0020,9111)  Frame Content Sequence  1 item(s) ----
#
#       ---------
#    (0020,9113)  Plane Position Sequence  1 item(s) ----
#       (0020,0032) Image Position (Patient)            DS: [-84.1245, -106.7583, 63.0000]
#       ---------
#    ---------
# (7FE0,0010) Pixel Data                          OW: Array of 342204416 elements
